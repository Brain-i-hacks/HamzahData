# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
os.chdir('D:\\Users\\Gebruiker\\Desktop\\Anita\'s rotzooi\\Tilburg University\\Brainihacks\\Hamzahacks')

# %%
RandomFirstR = pd.read_csv('RandomFirst_Random.csv')
RandomFirstA = pd.read_csv('RandomFirst_Adaptive.csv')
AdaptiveFirstA = pd.read_csv('AdaptiveFirst_Adaptive.csv')
AdaptiveFirstR = pd.read_csv('AdaptiveFirst_Random.csv')

# %%
#p10_R = np.array(RandomFirstR['P10'])
#p10_A = np.array(RandomFirstA['P10'])
RandomFirstA.head(5)
# Out:
#    Unnamed: 0       P10       P11       P14       P15       P18       P22  \
# 0           0  0.377609  0.336998  0.784049  0.533973  0.512391  0.489091
# 1           1  0.369909  0.331655  0.781959  0.535656  0.513387  0.491230
# 2           2  0.362985  0.326415  0.779868  0.537091  0.514090  0.493736
# 3           3  0.356787  0.321073  0.777673  0.538130  0.514383  0.496119
# 4           4  0.351315  0.315730  0.775792  0.538873  0.513973  0.498564
#
#         P23       P26       P27        P3       P30       P31        P6  \
# 0  0.262863  0.391632  0.239510  0.443185  0.371325  0.327510  0.180529
# 1  0.262158  0.392191  0.240932  0.438330  0.373451  0.326789  0.182881
# 2  0.261217  0.392191  0.242750  0.435416  0.375332  0.326148  0.185441
# 3  0.260277  0.392261  0.244883  0.434121  0.377581  0.325747  0.188002
# 4  0.259195  0.392261  0.247254  0.433878  0.379913  0.325347  0.190631
#
#          P7
# 0  0.573960
# 1  0.575121
# 2  0.575793
# 3  0.576221
# 4  0.576404

# %%
# Out:
#   File "C:\Users\GEBRUI~1\AppData\Local\Temp/ipykernel_5500/4119535456.py", line 1
#     P10 = np.concatenate((np.array(RandomFirstR['P10']), np.array(RandomFirstA['P10']), axis = 0))
#                                                                                              ^
# SyntaxError: invalid syntax

# %%
#Random = np.concatenate(RandomFirstR[:], RandomFirstA[:])
frames = [RandomFirstR, RandomFirstA]

Random = pd.concat(frames)
Random = Random.drop(columns=['Unnamed: 0'])
Random
# Out:
#             P10       P11       P14       P15       P18       P22       P23  \
# 0      0.377609  0.336998  0.784049  0.533973  0.512391  0.489091  0.262863
# 1      0.369909  0.331655  0.781959  0.535656  0.513387  0.491230  0.262158
# 2      0.362985  0.326415  0.779868  0.537091  0.514090  0.493736  0.261217
# 3      0.356787  0.321073  0.777673  0.538130  0.514383  0.496119  0.260277
# 4      0.351315  0.315730  0.775792  0.538873  0.513973  0.498564  0.259195
# ...         ...       ...       ...       ...       ...       ...       ...
# 14495  0.616435  0.665982  0.840807  0.487603  0.458140  0.474424  0.209670
# 14496  0.615951  0.658071  0.837567  0.486465  0.460250  0.475035  0.209905
# 14497  0.614595  0.649954  0.833281  0.484684  0.462769  0.475463  0.210234
# 14498  0.612803  0.642043  0.826278  0.482605  0.466284  0.475830  0.210516
# 14499  0.621374  0.634029  0.817393  0.480329  0.469623  0.475891  0.210705
#
# ...

# %%
mean = np.mean(Random, axis = 1)
plt.plot(mean)
plt.axhline(0.5, color = 'red')
plt.title('Random')

# %%
plt.plot(Random['P15'])
plt.axhline(0.5, color = 'red')
